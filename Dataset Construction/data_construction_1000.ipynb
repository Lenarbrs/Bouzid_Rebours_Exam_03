# %% [markdown]
# # 1. Library and data import

# %%
import pandas as pd

# %%
df_fake = pd.read_csv('Fake.csv') # Importing the dataset containing unreliable news
df_true = pd.read_csv('True.csv') # Importing the dataset containing truthful news

# %%
df_fake
# Out:
#                                                    title  \
# 0       Donald Trump Sends Out Embarrassing New Year’...
# 1       Drunk Bragging Trump Staffer Started Russian ...
# 2       Sheriff David Clarke Becomes An Internet Joke...
# 3       Trump Is So Obsessed He Even Has Obama’s Name...
# 4       Pope Francis Just Called Out Donald Trump Dur...
# ...                                                  ...
# 23476  McPain: John McCain Furious That Iran Treated ...
# 23477  JUSTICE? Yahoo Settles E-mail Privacy Class-ac...
# 23478  Sunnistan: US and Allied ‘Safe Zone’ Plan to T...
# 23479  How to Blow $700 Million: Al Jazeera America F...
# 23480  10 U.S. Navy Sailors Held by Iranian Military ...
#
#                                                     text      subject  \
# 0      Donald Trump just couldn t wish all Americans ...         News
# 1      House Intelligence Committee Chairman Devin Nu...         News
# ...

# %%
df_true
# Out:
#                                                    title  \
# 0      As U.S. budget fight looms, Republicans flip t...
# 1      U.S. military to accept transgender recruits o...
# 2      Senior U.S. Republican senator: 'Let Mr. Muell...
# 3      FBI Russia probe helped by Australian diplomat...
# 4      Trump wants Postal Service to charge 'much mor...
# ...                                                  ...
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text       subject  \
# 0      WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1      WASHINGTON (Reuters) - Transgender people will...  politicsNews
# ...

# %% [markdown]
# # 2. Data manipulation

# %%
# Drop duplicate titles and texts in each dataset to ensure each article only appears once
df_fake = df_fake.drop_duplicates(subset='title')
df_fake = df_fake.drop_duplicates(subset='text')
df_true = df_true.drop_duplicates(subset='title')
df_true = df_true.drop_duplicates(subset='text')
print(len(df_fake), len(df_true))
# Out:
# 17450 20821

# %%
df_fake.loc[:, 'fake'] = 1 # Set a "fake" label to the fake news
df_true.loc[:, 'fake'] = 0 # Set a "true" label to the real news

# %%
print((df_fake['fake'] == 1).all(), (df_true['fake'] == 0).all()) # Making sure all rows are correctly labelled
# Out:
# True True

# %%
df_fake_sample = df_fake.sample(n=500, random_state=42) # Randomly selecting 500 rows of the fake news dataset
df_true_sample = df_true.sample(n=500, random_state=42) # Randomly selecting 500 rows of the real news dataset

# %%
display(df_fake_sample, df_true_sample)
# Out:
#                                                    title  \
# 15543  GOP PRESIDENTIAL CANDIDATE MARCO RUBIO CASTS D...
# 1355    BREAKING: FBI Suspects Jared Kushner Of Being...
# 9145   JUST IN: FORMER NBC NEWS ANCHOR Tom Brokaw Tel...
# 19      Republican Senator Gets Dragged For Going Aft...
# 10276  FARMER FINED A WHOPPING $2.8 MILLION Asks Pres...
# ...                                                  ...
# 12239  #BoycottPenzeys: HATEFUL, DIVISIVE Penzeys Spi...
# 16106  SURREAL: Lone Venezuelan Man Plays Violin Amid...
# 4075    Eric Trump Just Got PUNKED By Latina Sisters ...
# 6915    WATCH: Someone Actually Bought And Drank Trum...
# 7467    MSNBC Host Can’t Help But Be Perfectly Sexist...
#
#                                                     text          subject  \
# 15543  One more Republican doing his part to aid Obam...         politics
# 1355   It was recently reported that someone within t...             News
# ...

# %%
df = pd.concat([df_fake_sample, df_true_sample], ignore_index=True) # Concatenate the datasets

# %%
df
# Out:
#                                                  title  \
# 0    GOP PRESIDENTIAL CANDIDATE MARCO RUBIO CASTS D...
# 1     BREAKING: FBI Suspects Jared Kushner Of Being...
# 2    JUST IN: FORMER NBC NEWS ANCHOR Tom Brokaw Tel...
# 3     Republican Senator Gets Dragged For Going Aft...
# 4    FARMER FINED A WHOPPING $2.8 MILLION Asks Pres...
# ..                                                 ...
# 995  Turks safe in Germany, Merkel says, dismissing...
# 996  U.S. renews call for Cambodia to release oppos...
# 997  France says will lead renewed effort to 'make ...
# 998  Obama calls for updates to government IT to pr...
# 999  Congress sends White House repeal of broadband...
#
#                                                   text       subject  \
# 0    One more Republican doing his part to aid Obam...      politics
# 1    It was recently reported that someone within t...          News
# 2    This morning, President Trump tweeted a note o...      politics
# ...

# %% [markdown]
# 5. Shuffling the data to ensure more safety if we cannot annotate the entire dataset due to Colab's restrictions

# %%
df_shuffled = df.sample(frac=1, random_state=42).reset_index(drop=True) # Shuffling the data to mix real and fake news and make the LLM annotation easier and safer in the case of an interrupt

# %%
df_shuffled
# Out:
#                                                  title  \
# 0    WTO chief won't debate Trump, but rallies supp...
# 1    Trump denounces attack in London, urges 'proac...
# 2    Trapped by landmines and a creek, Rohingya lan...
# 3    U.S. ends temporary protected status for Sudan...
# 4    OPEN SOCIETY: Soros-backed, Anti-Trump Immigra...
# ..                                                 ...
# 995   Hillary Clinton CRUSHES Donald Trump In This ...
# 996  AWESOME! WATCH REPUBLICAN STUDENTS Protest Awa...
# 997  Trump to host South Korea president June 29-30...
# 998  BUCKLE UP AMERICA: Dinesh D’Souza’s Is About T...
# 999   WATCH: Don Lemon CRUSHES Trump Supporter For ...
#
#                                                   text       subject  \
# 0    GENEVA (Reuters) - The head of the World Trade...  politicsNews
# 1    WASHINGTON (Reuters) - U.S. President Donald T...     worldnews
# 2    COX S BAZAR, Bangladesh Reuters) - Until late ...     worldnews
# ...

# %%
df_shuffled.to_csv('ISOT_1000_news.csv', index=False) # Saving the data
